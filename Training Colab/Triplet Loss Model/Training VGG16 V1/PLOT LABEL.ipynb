# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/PythonProject/Triplet Loss Model
# Out:
# /content/drive/MyDrive/PythonProject/Triplet Loss Model

# %%
import cv2
import pickle
import matplotlib.pyplot as plt
import numpy as np

# %%
with open("datasets/vn-celeb-dataset-rgb-450-people.p", "rb") as f:
    images = pickle.load(f)
    labels = pickle.load(f)

# %%
labels
# Out:
# array([  0,   0,   0, ..., 450, 450, 450], dtype=int32)

# %%
images.shape
# Out:
# (15490, 180, 180, 3)

# %%
img = images[35]
plt.imshow(img)

# %%
def count_elements(seq) -> dict:
    """Tally elements from `seq`."""
    hist = {}
    for i in seq:
        hist[i] = hist.get(i, 0) + 1
    return hist

counted = count_elements(labels)

# %%
import numpy as np
import matplotlib.pyplot as plt

alphab = ['A', 'B', 'C', 'D', 'E', 'F']
frequencies = [23, 44, 12, 11, 2, 10]

pos = np.arange(len(alphab))
width = 1.0     # gives histogram aspect to the bar diagram

ax = plt.axes()
ax.set_xticks(pos + (width / 2))
ax.set_xticklabels(alphab)

plt.bar(pos, frequencies, width, color='r')
plt.show()

# %%
width = 0.7

plt.bar(counted.keys(), counted.values(), width)
plt.show()
